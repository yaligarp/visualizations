# %% [markdown]
# # Indian Rainfall Analysis
#
# The 2019 Indian floods were a series of floods that affected over thirteen states in late July and early August 2019, due to incessant rains. At least 200 people died and about a million people were displaced. Karnataka and Maharashtra were the most severely affected states.
#
# It was the heaviest monsoon in the last 25 years. More than 1600 people died between June and October 2019.
#
# India being an agriculturally driven economy, it will be interesting to study the rainfall in India in the past decade to give us an idea of the changes in the pattern if there are any.
#
# Let us work on the INDIAN RAINFALL DATA!

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read the data

# %%
data = pd.read_csv('../data/rainfall in india 1901-2015.csv')

# %% [markdown]
# ## Summary of the data

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# 3   1977.6    571.0
# 4   1624.9    630.8

# %% [markdown]
# ## Inspect the data, find missing values and replace them with appropriate values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
# SUBDIVISION    4116 non-null object
# YEAR           4116 non-null int64
# JAN            4112 non-null float64
# FEB            4113 non-null float64
# MAR            4110 non-null float64
# APR            4112 non-null float64
# MAY            4113 non-null float64
# JUN            4111 non-null float64
# JUL            4109 non-null float64
# AUG            4112 non-null float64
# SEP            4110 non-null float64
# OCT            4109 non-null float64
# NOV            4105 non-null float64
# DEC            4106 non-null float64
# ANNUAL         4090 non-null float64
# Jan-Feb        4110 non-null float64
# Mar-May        4107 non-null float64
# Jun-Sep        4106 non-null float64
# Oct-Dec        4103 non-null float64
# dtypes: float64(17), int64(1), object(1)
# memory usage: 611.0+ KB

# %%
data.isnull().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data.loc[data.JAN.isnull(),['SUBDIVISION','YEAR']]
# Out:
#             SUBDIVISION  YEAR
# 148   ARUNACHAL PRADESH  1957
# 3653  COASTAL KARNATAKA  2012
# 4018        LAKSHADWEEP  1917
# 4031        LAKSHADWEEP  1931

# %%
data.loc[data.ANNUAL.isnull(),['SUBDIVISION','YEAR']]
# Out:
#                     SUBDIVISION  YEAR
# 21    ANDAMAN & NICOBAR ISLANDS  1923
# 22    ANDAMAN & NICOBAR ISLANDS  1924
# 30    ANDAMAN & NICOBAR ISLANDS  1932
# 34    ANDAMAN & NICOBAR ISLANDS  1936
# 40    ANDAMAN & NICOBAR ISLANDS  1942
# 42    ANDAMAN & NICOBAR ISLANDS  1947
# 110           ARUNACHAL PRADESH  1916
# 111           ARUNACHAL PRADESH  1917
# 144           ARUNACHAL PRADESH  1950
# 147           ARUNACHAL PRADESH  1953
# 148           ARUNACHAL PRADESH  1957
# 153           ARUNACHAL PRADESH  1962
# 1810            JAMMU & KASHMIR  2009
# 2146        WEST MADHYA PRADESH  2000
# 3653          COASTAL KARNATAKA  2012
# 4004                LAKSHADWEEP  1903
# 4018                LAKSHADWEEP  1917
# 4020                LAKSHADWEEP  1920
# 4021                LAKSHADWEEP  1921
# 4027                LAKSHADWEEP  1927
# 4028                LAKSHADWEEP  1928
# 4029                LAKSHADWEEP  1929
# 4031                LAKSHADWEEP  1931
# 4043                LAKSHADWEEP  1943
# 4046                LAKSHADWEEP  1946
# 4049                LAKSHADWEEP  1949

# %%
data['MY_ANNUAL']= data.iloc[:2:14].sum(axis=1)

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec  MY_ANNUAL
# 0   1696.3    980.3    12020.6
# 1   2185.9    716.7        NaN
# 2   1874.0    690.6        NaN
# 3   1977.6    571.0        NaN
# 4   1624.9    630.8        NaN

# %%
data.isnull().sum()
# Out:
# SUBDIVISION       0
# YEAR              0
# JAN               4
# FEB               3
# MAR               6
# APR               4
# MAY               3
# JUN               5
# JUL               7
# AUG               4
# SEP               6
# OCT               7
# NOV              11
# DEC              10
# ANNUAL           26
# Jan-Feb           6
# Mar-May           9
# Jun-Sep          10
# Oct-Dec          13
# MY_ANNUAL      4115
# dtype: int64

# %%
data.mean()
# Out:
# YEAR          1958.218659
# JAN             18.957320
# FEB             21.805325
# MAR             27.359197
# APR             43.127432
# MAY             85.745417
# JUN            230.234444
# JUL            347.214334
# AUG            290.263497
# SEP            197.361922
# OCT             95.507009
# NOV             39.866163
# DEC             18.870580
# ANNUAL        1411.008900
# Jan-Feb         40.747786
# Mar-May        155.901753
# Jun-Sep       1064.724769
# Oct-Dec        154.100487
# MY_ANNUAL    12020.600000
# dtype: float64

# %%
data.fillna(data.mean(), inplace=True)

# %%
#Can try
#data.fillna(data.groupby('SUBDIVISION').(mean),inplace = True)

# %% [markdown]
# ## Plot the mean annual rainfall and note down your observations regarding the same

# %%
mean_annual_rainfall=data.groupby('YEAR').ANNUAL.mean()

# %%
mean_annual_rainfall.name='Mean Annual Rainfall'
mean_annual_rainfall.plot()

# %%
#ALTERNATE way

# %%
na10=mean_annual_rainfall.rolling(10).mean()
na10.name='Moving avg for 10 yrs'
na10.plot(legend=True)

# %%
ax=data[['SUBDIVISION', 'Jan-Feb', 'Mar-May',
       'Jun-Sep', 'Oct-Dec']].groupby("SUBDIVISION").mean().sort_values('Jun-Sep').plot.bar(width=0.5,edgecolor='k',align='center',stacked=True,figsize=(16,8));

# Aesthetic of the plot
plt.xlabel('Subdivision',fontsize=30)
plt.ylabel('Rainfall (in mm)',fontsize=20)
plt.title('Rainfall in Subdivisions of India',fontsize=25)
ax.tick_params(labelsize=15)
plt.grid()
plt.ioff()

# %%
#(data.loc[:,['SUBDIVISION','Jan-Feb','Mar_May','Jun-Sep','Oct-Dec']].groupby('SUBDIVISION').mean().plot.bar(stacked=True,figsize(16,10)))

# %% [markdown]
# ## Similarly analyze the seasonal rainfall as per subdivisions and note down your observations

# %%
plt.figure(figsize=(23,10))
ax=sns.boxplot(x='SUBDIVISION', y='ANNUAL', data=data)
ax.tick_params(axis='x',labelsize=20,rotation=90)
ax.tick_params(axis='y',labelsize=20,rotation=0)

# %% [markdown]
# ## With boxplot analyze the distribution of rainfall in various states and onote down your observations

# %% [markdown]
# ## Analyze the rainfall through years in Kerala and note down your observations

# %%
Kerala = data[data.SUBDIVISION == 'KERALA']

# %%
# Plotting the average annual rainfall 
ax=Kerala.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000,5000),color='b',marker='o',linestyle='-',linewidth=2,figsize=(12,8));

# Setting up the aesthetics of the plot
plt.xlabel('Year',fontsize=20)
plt.ylabel('Kerala Annual Rainfall (in mm)',fontsize=20)
plt.title('Kerala Annual Rainfall from Year 1901 to 2015',fontsize=25)
ax.tick_params(labelsize=15)
plt.grid()
plt.ioff()

# %%
# ALTERNATIVE
kerala1= data.loc[data.SUBDIVISION == 'KERALA',: ]
kerala1.groupby('YEAR').ANNUAL.mean().plot()

# %%
#KERALA alternative end

# %%
# overlay plots
kerala1= data.loc[data.SUBDIVISION == 'KERALA',: ]
kerala1.groupby('YEAR').ANNUAL.mean().plot()
mean_annual_rainfall.plot()

# %% [markdown]
# ## Read the district wise rainfall data

# %%
Dist = pd.read_csv('../data/district wise rainfall normal.csv')
Dist.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# 1    483.5   1757.2    705.3
# 2    405.6   1884.4    574.7
# 3    841.3   1848.5    231.0
# 4    645.4   3008.4    268.1

# %%
# subsetting the Kerala state data
KDist=Dist[Dist.STATE_UT_NAME == 'KERALA']
k=KDist.sort_values(by=['ANNUAL'])

# plotting a bar plot to check districwise rainfall in Kerala
ax=k.plot.bar(x='DISTRICT',y='ANNUAL',width=0.5,edgecolor='k',align='center',linewidth=4,figsize=(16,8))

plt.xlabel('District',fontsize=30)
plt.ylabel('Annual Rainfall (in mm)',fontsize=20)
plt.title('Rainfall in Districts of Kerala',fontsize=25)
ax.tick_params(labelsize=20)
plt.grid()
plt.ioff()

# %% [markdown]
# ## Annual rainfall in different districts of Kerala

# %%
Dist.columns
# Out:
# Index([u'STATE_UT_NAME', u'DISTRICT', u'JAN', u'FEB', u'MAR', u'APR', u'MAY',
#        u'JUN', u'JUL', u'AUG', u'SEP', u'OCT', u'NOV', u'DEC', u'ANNUAL',
#        u'Jan-Feb', u'Mar-May', u'Jun-Sep', u'Oct-Dec'],
#       dtype='object')

# %%
Dist.DISTRICT.value_counts()
# Out:
# HAMIRPUR          2
# AURANGABAD        2
# BILASPUR          2
# BIJAPUR           2
# SENAPATI          1
# RAJOURI           1
# PULWAMA           1
# UKHRUL            1
# VIRUDHUNAGAR      1
# FATEHABAD         1
# SAWAI MADHOPUR    1
# GWALIOR           1
# DHARWAD           1
# RAE BARELI        1
# SITAPUR           1
# JHAJJAR           1
# BELLARY           1
# CHAMARAJANAGA     1
# ARARIA            1
# SOUTH TRIPURA     1
# PITHORAGARH       1
# NILGIRIS          1
# SRINAGAR          1
# WEST GARO HIL     1
# ADILABAD          1
# SUNDARGARH        1
# BARAN             1
# KORBA             1
# NARSINGHPUR       1
# BHIWANI           1
#                  ..
# SHAHDOL           1
# PANCHMAHALS       1
# SEHORE            1
# NORTH TRIPURA     1
# PURNEA            1
# SW DELHI          1
# UNNAO             1
# ANAND(KHR)        1
# SHRAVASTI NGR     1
# GARHWAL TEHRI     1
# ALIRAJPUR(JBA)    1
# MUMBAI CITY       1
# JAUNPUR           1
# MEWAT             1
# KHEDA             1
# DHANBAD           1
# MAHE              1
# WAYANAD           1
# NW DELHI          1
# HASSAN            1
# MAHASAMUND        1
# WEST MIDNAPOR     1
# CHAMPHAI          1
# HAILAKANDI        1
# PERAMBALUR        1
# TAWANG(W KAME     1
# BASTAR            1
# YADGIR            1
# YAVATMAL          1
# JALAUN            1
# Name: DISTRICT, Length: 637, dtype: int64

# %% [markdown]
# ## Similarly, find districts with maximum rainfall

# %%
#Dist.groupby('DISTRICT').ANNUAL.max().nlargest(10)

Dist.groupby(['STATE_UT_NAME','DISTRICT'])['ANNUAL'].max().nlargest(10).plot.barh()
